# %%
# ==============================
# STEP 1: Install Java & Hadoop
# ==============================
# !apt-get update -y
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download Hadoop 3.3.6
# !wget -q https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /usr/local/hadoop

# ==============================
# STEP 2: Setup Hadoop Env
# ==============================
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop"
os.environ["PATH"] = f"{os.environ['HADOOP_HOME']}/bin:{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]

# !hadoop version
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,080 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,816 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,742 kB]
# Get:15 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,755 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,368 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,278 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,429 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,584 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,936 kB]
# Fetched 36.4 MB in 4s (8,327 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# ==============================
# STEP 3: Prepare Input Files
# ==============================
# !mkdir input_data

with open("input_data/input1.txt", "w") as f:
    f.write("Hello World Bye World\n")

with open("input_data/input2.txt", "w") as f:
    f.write("Hello Hadoop Goodbye Hadoop\n")

# !cat input_data/*
# Out:
# Hello World Bye World
# Hello Hadoop Goodbye Hadoop

# %%
# %%bash
# cat > mapper.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# for line in sys.stdin:
#     line = line.strip()
#     for word in line.split():
#         print(f"{word}\t1")
# EOF
#
# cat > combiner.py <<'EOF'
# #!/usr/bin/env python3
# import sys
# from collections import defaultdict
#
# counts = defaultdict(int)
# for line in sys.stdin:
#     word, count = line.strip().split("\t")
#     counts[word] += int(count)
#
# for word, count in counts.items():
#     print(f"{word}\t{count}")
# EOF
#
# cat > reducer.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# current_word = None
# current_count = 0
#
# for line in sys.stdin:
#     word, count = line.strip().split("\t")
#     count = int(count)
#
#     if current_word == word:
#         current_count += count
#     else:
#         if current_word:
#             print(f"{current_word}\t{current_count}")
#         current_word = word
#         current_count = count
#
# if current_word:
#     print(f"{current_word}\t{current_count}")
# EOF
#
# chmod +x mapper.py combiner.py reducer.py

# %%
# ==============================
# STEP 5: Run Hadoop Streaming Job
# ==============================
# !hadoop fs -rm -r -f input output

# Put input files into HDFS
# !hadoop fs -mkdir -p input
# !hadoop fs -put input_data/* input/

# Run Hadoop Streaming
# !hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-*.jar \
  -input input \
  -output output \
  -mapper mapper.py \
  -combiner combiner.py \
  -reducer reducer.py \
  -file mapper.py \
  -file combiner.py \
  -file reducer.py
# Out:
# 2025-10-15 16:21:21,263 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py, combiner.py, reducer.py] [] /tmp/streamjob1633965402820823746.jar tmpDir=null
# 2025-10-15 16:21:21,801 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-10-15 16:21:21,896 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-10-15 16:21:21,896 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-10-15 16:21:21,915 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-10-15 16:21:22,133 INFO mapred.FileInputFormat: Total input files to process : 2
# 2025-10-15 16:21:22,149 INFO mapreduce.JobSubmitter: number of splits:2
# 2025-10-15 16:21:22,305 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1787035994_0001
# 2025-10-15 16:21:22,305 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2025-10-15 16:21:22,571 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper.py as file:/tmp/hadoop-root/mapred/local/job_local1787035994_0001_4aeac4e0-7e0b-4a08-aea6-9ce915169636/mapper.py
# 2025-10-15 16:21:22,598 INFO mapred.LocalDistributedCacheManager: Localized file:/content/combiner.py as file:/tmp/hadoop-root/mapred/local/job_local1787035994_0001_f2d3e5f7-d294-4dd3-8cde-3f4ab8f9bffc/combiner.py
# 2025-10-15 16:21:22,599 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer.py as file:/tmp/hadoop-root/mapred/local/job_local1787035994_0001_7ab36e73-05d7-4a8b-a622-b44f70ee1656/reducer.py
# 2025-10-15 16:21:22,691 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-10-15 16:21:22,694 INFO mapreduce.Job: Running job: job_local1787035994_0001
# 2025-10-15 16:21:22,692 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-10-15 16:21:22,697 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2025-10-15 16:21:22,778 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 16:21:22,778 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 16:21:22,816 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2025-10-15 16:21:22,821 INFO mapred.LocalJobRunner: Starting task: attempt_local1787035994_0001_m_000000_0
# 2025-10-15 16:21:22,851 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 16:21:22,852 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 16:21:22,880 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-15 16:21:22,893 INFO mapred.MapTask: Processing split: file:/content/input/input2.txt:0+28
# 2025-10-15 16:21:22,903 INFO mapred.MapTask: numReduceTasks: 1
# 2025-10-15 16:21:22,960 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-10-15 16:21:22,960 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-10-15 16:21:22,960 INFO mapred.MapTask: soft limit at 83886080
# 2025-10-15 16:21:22,960 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-10-15 16:21:22,960 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-10-15 16:21:22,966 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-10-15 16:21:22,971 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-10-15 16:21:22,975 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2025-10-15 16:21:22,976 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2025-10-15 16:21:22,976 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2025-10-15 16:21:22,976 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2025-10-15 16:21:22,977 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2025-10-15 16:21:22,977 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2025-10-15 16:21:22,978 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2025-10-15 16:21:22,979 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2025-10-15 16:21:22,979 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2025-10-15 16:21:22,979 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2025-10-15 16:21:22,980 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-10-15 16:21:22,980 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-10-15 16:21:22,999 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 16:21:23,053 INFO streaming.PipeMapRed: Records R/W=1/1
# 2025-10-15 16:21:23,059 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 16:21:23,060 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 16:21:23,062 INFO mapred.LocalJobRunner:
# 2025-10-15 16:21:23,062 INFO mapred.MapTask: Starting flush of map output
# 2025-10-15 16:21:23,062 INFO mapred.MapTask: Spilling map output
# 2025-10-15 16:21:23,062 INFO mapred.MapTask: bufstart = 0; bufend = 36; bufvoid = 104857600
# 2025-10-15 16:21:23,062 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214384(104857536); length = 13/6553600
# 2025-10-15 16:21:23,074 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-10-15 16:21:23,076 INFO Configuration.deprecation: mapred.skip.map.auto.incr.proc.count is deprecated. Instead, use mapreduce.map.skip.proc-count.auto-incr
# 2025-10-15 16:21:23,090 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 16:21:23,140 INFO streaming.PipeMapRed: Records R/W=4/1
# 2025-10-15 16:21:23,147 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 16:21:23,147 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 16:21:23,147 INFO mapred.MapTask: Finished spill 0
# 2025-10-15 16:21:23,160 INFO mapred.Task: Task:attempt_local1787035994_0001_m_000000_0 is done. And is in the process of committing
# 2025-10-15 16:21:23,162 INFO mapred.LocalJobRunner: Records R/W=4/1
# 2025-10-15 16:21:23,162 INFO mapred.Task: Task 'attempt_local1787035994_0001_m_000000_0' done.
# 2025-10-15 16:21:23,170 INFO mapred.Task: Final Counters for attempt_local1787035994_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=1940
# 		FILE: Number of bytes written=646217
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=4
# 		Map output bytes=36
# 		Map output materialized bytes=39
# 		Input split bytes=82
# 		Combine input records=4
# 		Combine output records=3
# 		Spilled Records=3
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=316145664
# 	File Input Format Counters
# 		Bytes Read=44
# 2025-10-15 16:21:23,170 INFO mapred.LocalJobRunner: Finishing task: attempt_local1787035994_0001_m_000000_0
# 2025-10-15 16:21:23,170 INFO mapred.LocalJobRunner: Starting task: attempt_local1787035994_0001_m_000001_0
# 2025-10-15 16:21:23,171 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 16:21:23,171 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 16:21:23,172 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-15 16:21:23,174 INFO mapred.MapTask: Processing split: file:/content/input/input1.txt:0+22
# 2025-10-15 16:21:23,178 INFO mapred.MapTask: numReduceTasks: 1
# 2025-10-15 16:21:23,228 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-10-15 16:21:23,228 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-10-15 16:21:23,228 INFO mapred.MapTask: soft limit at 83886080
# 2025-10-15 16:21:23,228 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-10-15 16:21:23,228 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-10-15 16:21:23,229 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-10-15 16:21:23,232 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-10-15 16:21:23,249 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 16:21:23,318 INFO streaming.PipeMapRed: Records R/W=1/1
# 2025-10-15 16:21:23,329 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 16:21:23,329 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 16:21:23,330 INFO mapred.LocalJobRunner:
# 2025-10-15 16:21:23,330 INFO mapred.MapTask: Starting flush of map output
# 2025-10-15 16:21:23,330 INFO mapred.MapTask: Spilling map output
# 2025-10-15 16:21:23,330 INFO mapred.MapTask: bufstart = 0; bufend = 30; bufvoid = 104857600
# 2025-10-15 16:21:23,330 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214384(104857536); length = 13/6553600
# 2025-10-15 16:21:23,335 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-10-15 16:21:23,347 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 16:21:23,394 INFO streaming.PipeMapRed: Records R/W=4/1
# 2025-10-15 16:21:23,402 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 16:21:23,402 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 16:21:23,402 INFO mapred.MapTask: Finished spill 0
# 2025-10-15 16:21:23,405 INFO mapred.Task: Task:attempt_local1787035994_0001_m_000001_0 is done. And is in the process of committing
# 2025-10-15 16:21:23,406 INFO mapred.LocalJobRunner: Records R/W=4/1
# 2025-10-15 16:21:23,406 INFO mapred.Task: Task 'attempt_local1787035994_0001_m_000001_0' done.
# 2025-10-15 16:21:23,407 INFO mapred.Task: Final Counters for attempt_local1787035994_0001_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2161
# 		FILE: Number of bytes written=646283
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=4
# 		Map output bytes=30
# 		Map output materialized bytes=34
# 		Input split bytes=82
# 		Combine input records=4
# 		Combine output records=3
# 		Spilled Records=3
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=421527552
# 	File Input Format Counters
# 		Bytes Read=38
# 2025-10-15 16:21:23,407 INFO mapred.LocalJobRunner: Finishing task: attempt_local1787035994_0001_m_000001_0
# 2025-10-15 16:21:23,407 INFO mapred.LocalJobRunner: map task executor complete.
# 2025-10-15 16:21:23,410 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-10-15 16:21:23,410 INFO mapred.LocalJobRunner: Starting task: attempt_local1787035994_0001_r_000000_0
# 2025-10-15 16:21:23,417 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 16:21:23,417 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 16:21:23,417 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-15 16:21:23,420 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@7061c2c4
# 2025-10-15 16:21:23,422 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-10-15 16:21:23,441 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2116865152, maxSingleShuffleLimit=529216288, mergeThreshold=1397131008, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-10-15 16:21:23,445 INFO reduce.EventFetcher: attempt_local1787035994_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-10-15 16:21:23,477 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1787035994_0001_m_000000_0 decomp: 35 len: 39 to MEMORY
# 2025-10-15 16:21:23,480 INFO reduce.InMemoryMapOutput: Read 35 bytes from map-output for attempt_local1787035994_0001_m_000000_0
# 2025-10-15 16:21:23,482 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 35, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->35
# 2025-10-15 16:21:23,484 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1787035994_0001_m_000001_0 decomp: 30 len: 34 to MEMORY
# 2025-10-15 16:21:23,487 INFO reduce.InMemoryMapOutput: Read 30 bytes from map-output for attempt_local1787035994_0001_m_000001_0
# 2025-10-15 16:21:23,487 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 30, inMemoryMapOutputs.size() -> 2, commitMemory -> 35, usedMemory ->65
# 2025-10-15 16:21:23,488 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-10-15 16:21:23,488 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-10-15 16:21:23,490 INFO reduce.MergeManagerImpl: finalMerge called with 2 in-memory map-outputs and 0 on-disk map-outputs
# 2025-10-15 16:21:23,496 INFO mapred.Merger: Merging 2 sorted segments
# 2025-10-15 16:21:23,496 INFO mapred.Merger: Down to the last merge-pass, with 2 segments left of total size: 49 bytes
# 2025-10-15 16:21:23,497 INFO reduce.MergeManagerImpl: Merged 2 segments, 65 bytes to disk to satisfy reduce memory limit
# 2025-10-15 16:21:23,498 INFO reduce.MergeManagerImpl: Merging 1 files, 67 bytes from disk
# 2025-10-15 16:21:23,499 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-10-15 16:21:23,499 INFO mapred.Merger: Merging 1 sorted segments
# 2025-10-15 16:21:23,499 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 57 bytes
# 2025-10-15 16:21:23,500 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-10-15 16:21:23,502 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer.py]
# 2025-10-15 16:21:23,505 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-10-15 16:21:23,506 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2025-10-15 16:21:23,523 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 16:21:23,580 INFO streaming.PipeMapRed: Records R/W=6/1
# 2025-10-15 16:21:23,587 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 16:21:23,587 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 16:21:23,588 INFO mapred.Task: Task:attempt_local1787035994_0001_r_000000_0 is done. And is in the process of committing
# 2025-10-15 16:21:23,589 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-10-15 16:21:23,589 INFO mapred.Task: Task attempt_local1787035994_0001_r_000000_0 is allowed to commit now
# 2025-10-15 16:21:23,590 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1787035994_0001_r_000000_0' to file:/content/output
# 2025-10-15 16:21:23,591 INFO mapred.LocalJobRunner: Records R/W=6/1 > reduce
# 2025-10-15 16:21:23,592 INFO mapred.Task: Task 'attempt_local1787035994_0001_r_000000_0' done.
# 2025-10-15 16:21:23,592 INFO mapred.Task: Final Counters for attempt_local1787035994_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2365
# 		FILE: Number of bytes written=646403
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=73
# 		Reduce input records=6
# 		Reduce output records=5
# 		Spilled Records=6
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=421527552
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=53
# 2025-10-15 16:21:23,593 INFO mapred.LocalJobRunner: Finishing task: attempt_local1787035994_0001_r_000000_0
# 2025-10-15 16:21:23,593 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2025-10-15 16:21:23,777 INFO mapreduce.Job: Job job_local1787035994_0001 running in uber mode : false
# 2025-10-15 16:21:23,778 INFO mapreduce.Job:  map 100% reduce 100%
# 2025-10-15 16:21:23,779 INFO mapreduce.Job: Job job_local1787035994_0001 completed successfully
# 2025-10-15 16:21:23,786 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=6466
# 		FILE: Number of bytes written=1938903
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=2
# 		Map output records=8
# 		Map output bytes=66
# 		Map output materialized bytes=73
# 		Input split bytes=164
# 		Combine input records=8
# 		Combine output records=6
# 		Reduce input groups=5
# 		Reduce shuffle bytes=73
# 		Reduce input records=6
# 		Reduce output records=5
# 		Spilled Records=12
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=1159200768
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=82
# 	File Output Format Counters
# 		Bytes Written=53
# 2025-10-15 16:21:23,786 INFO streaming.StreamJob: Output directory: output

# %%
# ==============================
# STEP 6: Check Output
# ==============================
# !hadoop fs -cat output/part-00000
# Out:
# Bye	1
# Goodbye	1
# Hadoop	2
# Hello	2
# World	2
